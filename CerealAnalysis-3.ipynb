# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data=pd.read_csv('primary_dataset.csv')

# %%
sns.boxplot(y=data['rating'],x=data['mfr']).set_title('Rating by Manufacturer Name')
# Out:
# Text(0.5, 1.0, 'Rating by Manufacturer Name')

# %%
data[data['mfr']=='N'] # cluster one
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# ...

# %%
data[data['name']=='All-Bran with Extra Fiber'] # the best cereal
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3    8.0       0     330        25      3     1.0   0.5  93.704912

# %%
data[(data['mfr']!= 'N') & (data['name']!='All-Bran with Extra Fiber') ] #cluster three
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 1         100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                  All-Bran   K    C        70        4    1     260    9.0
# 4            Almond Delight   R    C       110        2    2     200    1.0
# 5   Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6               Apple Jacks   K    C       110        2    0     125    1.0
# ..                      ...  ..  ...       ...      ...  ...     ...    ...
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
#https://stackoverflow.com/questions/39409866/correlation-heatmap
import seaborn as sns

# calculate the correlation matrix
corr = data[(data['mfr']!='N') & (data['name']!='All-Bran with Extra Fiber')].corr()# cluster two
ax2 = plt.axes()
# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,cmap="RdGy",ax=ax2,square=True,cbar=False,fmt='d')
ax2.set_title('Tier 3: Excluding Nabisco and All-Bran with Extra Fiber')
# Out:
# Text(0.5, 1, 'Tier 3: Excluding Nabisco and All-Bran with Extra Fiber')

# %%
#https://stackoverflow.com/questions/39409866/correlation-heatmap
import seaborn as sns

# calculate the correlation matrix
corr = data[(data['mfr']=='N') & (data['name']!='All-Bran with Extra Fiber')].corr()# cluster two
ax2 = plt.axes()
# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,cmap="RdGy",ax=ax2,square=True,cbar=False,fmt='d')
ax2.set_title('Tier 2: Nabisco')
# Out:
# Text(0.5, 1, 'Tier 2: Nabisco')

# %%
#Randomforest

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=5,random_state=0)
x=data.iloc[:,15].values# target selection
kmeans.fit(x.reshape(-1,1))
y_kmeans=kmeans.predict(x.reshape(-1,1))
#https://stackoverflow.com/questions/12444716/how-do-i-set-the-figure-title-and-axes-labels-font-size-in-matplotlib
plt.scatter(y_kmeans,x.reshape(-1,1),s=50,cmap='viridis',c=y_kmeans)
plt.xlabel('K-Means Score')
plt.ylabel('Rating')
plt.suptitle('K-Means Score Versus Rating')
grade_dict={4:'F',0:'D',3:'C',1:'B',2:'A'}
dictionary=pd.Series(grade_dict)
subset=data.loc[:,'name':'rating']
K_rating=pd.DataFrame(dictionary[y_kmeans].reset_index().iloc[:,1])
my_df=pd.concat([subset,K_rating],axis=1)
my_df=my_df.rename(columns = {0:'K-Means Grade'}) # re-naming column
my_df
#Citation: (Don't erase) https://stackoverflow.com/questions/27719407/pandas-concat-valueerror-shape-of-passed-values-is-blah-indices-imply-blah2
#it turns out there's more than 3 clusters
#the best cereal is the only A grade cereal
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
my_df[my_df['mfr']=='N'] # cluster one
#all the nabisco cereals are B grade
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# ...

# %%
my_df[(my_df['mfr']!= 'N') & (my_df['name']!='All-Bran with Extra Fiber') ] #cluster three
#diversity of ratings
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 1         100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                  All-Bran   K    C        70        4    1     260    9.0
# 4            Almond Delight   R    C       110        2    2     200    1.0
# 5   Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6               Apple Jacks   K    C       110        2    0     125    1.0
# ..                      ...  ..  ...       ...      ...  ...     ...    ...
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
X=my_df.iloc[:,3:14]
X
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      -1        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight
# 0       3     1.0
# 1       3     1.0
# ...

# %%
y=my_df.iloc[:,16]
y
# Out:
# 0     B
# 1     D
# 2     B
# 3     A
# 4     D
#      ..
# 72    D
# 73    F
# 74    C
# 75    C
# 76    D
# Name: K-Means Grade, Length: 77, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier
X=my_df.iloc[:,3:14].values
y=my_df.iloc[:,16].values

# %%
# YOUR CODE HERE
from sklearn.preprocessing import Normalizer

transformer = Normalizer()
a = Normalizer().fit_transform(X)

# %%
#unnormlized X accuracy is 0.50
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0,
                                  train_size=0.3)
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(Xtrain,ytrain)
Y_pred=knn.predict(Xtest)
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(ytest,Y_pred))
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,Y_pred))
print(classification_report(ytest,Y_pred))
# Out:
# Accuracy: 0.4074074074074074
# [[ 0  0  1  0  0]
#  [ 0  5  2  1  0]
#  [ 0  3  3  4  2]
#  [ 0  1 10  6  5]
#  [ 0  0  2  1  8]]
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         1
#            B       0.56      0.62      0.59         8
#            C       0.17      0.25      0.20        12
#            D       0.50      0.27      0.35        22
#            F       0.53      0.73      0.62        11
#
#     accuracy                           0.41        54
#    macro avg       0.35      0.38      0.35        54
# weighted avg       0.43      0.41      0.40        54
# /opt/apps/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(a, y, random_state=0,
                                  train_size=0.3)
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(Xtrain,ytrain)
Y_pred=knn.predict(Xtest)
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(ytest,Y_pred))
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,Y_pred))
print(classification_report(ytest,Y_pred))
# Out:
# Accuracy: 0.5
# [[0 0 0 1 0]
#  [0 5 1 2 0]
#  [0 3 4 5 0]
#  [0 1 8 9 4]
#  [0 0 1 1 9]]
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         1
#            B       0.56      0.62      0.59         8
#            C       0.29      0.33      0.31        12
#            D       0.50      0.41      0.45        22
#            F       0.69      0.82      0.75        11
#
#     accuracy                           0.50        54
#    macro avg       0.41      0.44      0.42        54
# weighted avg       0.49      0.50      0.49        54
# /opt/apps/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#normalized X accuracy is 0.5

from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(a1, y, random_state=0,
                                  train_size=0.3)
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(Xtrain,ytrain)
Y_pred=knn.predict(Xtest)
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(ytest,Y_pred))
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,Y_pred))
print(classification_report(ytest,Y_pred))
# Out:
# Accuracy: 0.5
# [[0 0 0 1 0]
#  [0 5 1 2 0]
#  [0 3 4 5 0]
#  [0 1 8 9 4]
#  [0 0 1 1 9]]
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         1
#            B       0.56      0.62      0.59         8
#            C       0.29      0.33      0.31        12
#            D       0.50      0.41      0.45        22
#            F       0.69      0.82      0.75        11
#
#     accuracy                           0.50        54
#    macro avg       0.41      0.44      0.42        54
# weighted avg       0.49      0.50      0.49        54
# /opt/apps/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
error_rate = []
#medium article script
k=range(1,15)
for i in k:
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(Xtrain,ytrain)
    pred_i = knn.predict(Xtest)
    error_rate.append(np.mean(pred_i != ytest))
plt.figure(figsize=(10,6))
plt.plot(k,error_rate)
#5 neighbors is optimal

# %%
X=my_df.iloc[:,3:15]
X
y=my_df.iloc[:,16]
y
from sklearn.preprocessing import Normalizer
transformer = Normalizer()
a = Normalizer().fit_transform(X)
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(a, y, random_state=0,
                                  train_size=0.3)
X
# YOUR CODE HERE
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      -1        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups
# 0       3     1.0  0.33
# ...

# %%
from sklearn.svm import SVC # "Support vector classifier"
clf = SVC(kernel='rbf',C=1e4) # 'rbf' stands for RADIAL BASIS FUNCTION 
clf.fit(Xtrain, ytrain)#can't us a continuous predicted variable
clf.predict(Xtest)
from sklearn.metrics import accuracy_score
print("Accuracy: ", accuracy_score(ytest,clf.predict(Xtest)))
print(classification_report(ytest,clf.predict(Xtest)))
# Out:
# Accuracy:  0.42592592592592593
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         1
#            B       0.44      0.50      0.47         8
#            C       0.14      0.17      0.15        12
#            D       0.42      0.36      0.39        22
#            F       0.75      0.82      0.78        11
#
#     accuracy                           0.43        54
#    macro avg       0.35      0.37      0.36        54
# weighted avg       0.42      0.43      0.42        54
# /opt/apps/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X=my_df.iloc[:,3:15]
X
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      -1        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups
# 0       3     1.0  0.33
# ...

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0,
                                  train_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB
estimator=GaussianNB()
estimator.fit(Xtrain,ytrain)
labels=estimator.predict(Xtest)
labels
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(ytest,labels)
mat
sns.heatmap(mat,annot=True)
plt.xlabel('predicted label')
plt.ylabel('true label')

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(ytest,labels))
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,labels))
print(classification_report(ytest,labels))
# Out:
# Accuracy: 0.35185185185185186
# [[ 0  0  1  0  0]
#  [ 0  0  3  5  0]
#  [ 0  0  6  4  2]
#  [ 0  0  8  3 11]
#  [ 0  0  0  1 10]]
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         1
#            B       0.00      0.00      0.00         8
#            C       0.33      0.50      0.40        12
#            D       0.23      0.14      0.17        22
#            F       0.43      0.91      0.59        11
#
#     accuracy                           0.35        54
#    macro avg       0.20      0.31      0.23        54
# weighted avg       0.26      0.35      0.28        54
# /opt/apps/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X=my_df.iloc[:,0]
X
# Out:
# 0                     100% Bran
# 1             100% Natural Bran
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 4                Almond Delight
#                 ...
# 72                      Triples
# 73                         Trix
# 74                   Wheat Chex
# 75                     Wheaties
# 76          Wheaties Honey Gold
# Name: name, Length: 77, dtype: object

# %%
y=my_df.iloc[:,1]
y
# Out:
# 0     N
# 1     Q
# 2     K
# 3     K
# 4     R
#      ..
# 72    G
# 73    G
# 74    R
# 75    G
# 76    G
# Name: mfr, Length: 77, dtype: object

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0,
                                  train_size=0.3)

# %%
#using cereal name to predict manufacturer
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
estimator=make_pipeline(TfidfVectorizer(),MultinomialNB())
estimator.fit(Xtrain,ytrain)
labels=estimator.predict(Xtest)
labels
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(ytest,labels)
mat
sns.heatmap(mat,annot=True)
plt.xlabel('predicted label')
plt.ylabel('true label')

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(ytest,labels))
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,labels))
print(classification_report(ytest,labels))
# Out:
# Accuracy: 0.2777777777777778
# [[ 0  0  1  0  0  0  0]
#  [ 0  3 12  0  0  0  0]
#  [ 0  3 11  0  0  0  0]
#  [ 0  0  2  1  0  0  0]
#  [ 0  1  6  0  0  0  0]
#  [ 0  3  5  0  0  0  0]
#  [ 0  0  6  0  0  0  0]]
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         1
#            G       0.30      0.20      0.24        15
#            K       0.26      0.79      0.39        14
#            N       1.00      0.33      0.50         3
#            P       0.00      0.00      0.00         7
#            Q       0.00      0.00      0.00         8
#            R       0.00      0.00      0.00         6
#
#     accuracy                           0.28        54
#    macro avg       0.22      0.19      0.16        54
# weighted avg       0.21      0.28      0.19        54
# ...

# %%
X=my_df.iloc[:,0]
X
# Out:
# 0                     100% Bran
# 1             100% Natural Bran
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 4                Almond Delight
#                 ...
# 72                      Triples
# 73                         Trix
# 74                   Wheat Chex
# 75                     Wheaties
# 76          Wheaties Honey Gold
# Name: name, Length: 77, dtype: object

# %%
y=my_df.iloc[:,16]
y
# Out:
# 0     B
# 1     D
# 2     B
# 3     A
# 4     D
#      ..
# 72    D
# 73    F
# 74    C
# 75    C
# 76    D
# Name: K-Means Grade, Length: 77, dtype: object

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0,
                                  train_size=0.3)

# %%
#using cereal name to predict manufacturer
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
estimator=make_pipeline(TfidfVectorizer(),MultinomialNB())
estimator.fit(Xtrain,ytrain)
labels=estimator.predict(Xtest)
labels
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(ytest,labels)
mat
sns.heatmap(mat,annot=True)
plt.xlabel('predicted label')
plt.ylabel('true label')

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(ytest,labels))
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,labels))
print(classification_report(ytest,labels))
# Out:
# Accuracy: 0.3888888888888889
# [[ 0  0  1  0  0]
#  [ 0  2  3  1  2]
#  [ 0  0  3  0  9]
#  [ 0  0  6  6 10]
#  [ 0  0  1  0 10]]
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         1
#            B       1.00      0.25      0.40         8
#            C       0.21      0.25      0.23        12
#            D       0.86      0.27      0.41        22
#            F       0.32      0.91      0.48        11
#
#     accuracy                           0.39        54
#    macro avg       0.48      0.34      0.30        54
# weighted avg       0.61      0.39      0.38        54
# /opt/apps/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
my_df.to_csv('final.csv')

# %% [markdown]
# r <- read.csv(file.choose())
# library(nlme)
# r$pv <- r$vitamins / r$potass
# r[r$mfr == "A"]
# r <- subset(r, r$mfr != "A")
# my.lme <-
#   lme(
#     rating ~ calories + protein + fat + sodium + fat + fiber + carbo + sugars +
#       pv + shelf + weight + cups,
#     random =  ~ 1 |
#       as.numeric(name),
#     method = "REML",
#     data = r,
#     control = lmeControl(maxIter = 1000, tolerance = 1e-10)
#   )
